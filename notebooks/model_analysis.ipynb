# %% [markdown]
# ## Update log
#
# - 2025-12-17: Added a learned projection for cached ESM embeddings. When the input cache is 1280-d and `model.seq_embeddings.feature_dim` is smaller, the model projects embeddings to the configured feature_dim before DCCN/seq_gating, reducing downstream memory. `scripts/main.py` now preserves the model feature_dim and records the raw ESM width via `model.seq_embeddings.raw_dim` from manifest metadata.

# %%
import numpy as np

# %%
hi = np.load(r"/orcd/home/002/lerchen/code/cafa_proj/data/manifests/train/bp_manifest_neighbors_top20.npz")

# %%
print(len(hi['neighbors'][0]))
print((hi['weights'][0]))
# Out:
# 20
# [0.9976 0.9214 0.904  0.903  0.902  0.9014 0.9004 0.8975 0.8975 0.897
#  0.897  0.897  0.8965 0.896  0.896  0.896  0.8955 0.894  0.894  0.894 ]
